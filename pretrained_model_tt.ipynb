# %% [markdown]
# <a href="https://colab.research.google.com/github/sjos226/Machine-Learning/blob/main/pretrained_model_tt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers sentencepiece

# %%
from transformers import pipeline

# Load your CSV file into a DataFrame
csv_file_path = "/content/viet_5k.csv"
df = pd.read_csv(csv_file_path)

# Create the translation pipeline
translation_pipe = pipeline("translation", model="Helsinki-NLP/opus-mt-vi-en")

# Translate each row in the DataFrame and save to a list
translated_texts = []
for index, row in df.iterrows():
    vietnamese_text = row['vietnamese']  # Replace 'VietnameseColumn' with the actual column name in your CSV
    translated_text = translation_pipe(vietnamese_text)[0]['translation_text']

    # Print the translation to the console
    print(f"Original text (Vietnamese): {vietnamese_text}")
    print(f"Translated text (English): {translated_text}\n")

    translated_texts.append(translated_text)

# Save the translated texts to a text file
output_txt_path = "translated_output.txt"
with open(output_txt_path, 'w', encoding='utf-8') as txt_file:
    txt_file.write('\n'.join(translated_texts))

print(f"Translation completed. Translated data saved to: {output_txt_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/models/marian/tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Streaming output truncated to the last 5000 lines.
# Original text (Vietnamese): Tôi nghĩ Mao Trạch Đông nắm được điều đó.।
# Translated text (English): I think Mao Tse Tung has it.
#
# Original text (Vietnamese): Ông ta không phải là một nhà chiến lược quân sự giỏi nhưng ông ta hiểu lúc bấy giờ Mỹ không có ý chí chính trị để bảo vệ Việt Nam Cộng Hòa.।
# Translated text (English): He wasn't a very good military tactician, but he understood at the time that the U.S. didn't have the political will to protect the Republic.
#
# Original text (Vietnamese): Hãy nhớ rằng Kissinger đã bỏ rơi Đài Loan bởi ông ấy nghĩ Mỹ cần một Trung Quốc mạnh để đối phó với Liên Xô.।
# ...
